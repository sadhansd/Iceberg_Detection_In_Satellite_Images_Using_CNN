# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # TASK-1
# Create a pandas dataframe (DataFrame name as 'df') with numpy random values (4 features and 4 observation)

# %%
s1 = pd.Series(np.random.rand(4))
s2 = pd.Series(np.random.rand(4))
s3 = pd.Series(np.random.rand(4))
s4 = pd.Series(np.random.rand(4))

# %%
df = pd.DataFrame([s1,s2,s3,s4])
df
# Out:
#           0         1         2         3
# 0  0.166981  0.530027  0.316592  0.746630
# 1  0.759591  0.538733  0.432435  0.211435
# 2  0.569297  0.790370  0.780319  0.329073
# 3  0.502208  0.661269  0.501653  0.093722

# %% [markdown]
# # TASK - 2
# Rename the task - 1 'df' dataframe column names to 'Random value 1', 'Random value 2', 'Random value 3' & 'Random value 4'

# %%
df.columns = ['Random value 1','Random value 2','Random value 3','Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.166981        0.530027        0.316592        0.746630
# 1        0.759591        0.538733        0.432435        0.211435
# 2        0.569297        0.790370        0.780319        0.329073
# 3        0.502208        0.661269        0.501653        0.093722

# %% [markdown]
# # TASK - 3
# Find the descriptive statistics of the 'df' dataframe

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.499519        0.630100        0.507750        0.345215
# std          0.247046        0.122502        0.197100        0.284336
# min          0.166981        0.530027        0.316592        0.093722
# 25%          0.418401        0.536557        0.403474        0.182007
# 50%          0.535752        0.600001        0.467044        0.270254
# 75%          0.616870        0.693544        0.571320        0.433462
# max          0.759591        0.790370        0.780319        0.746630

# %% [markdown]
# # TASK - 4
# Check for the null values in 'df' and find the data type of the columns.

# %%
df.isnull()
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
df.isnull().sum()
# Out:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64

# %%
df.iloc[0,2] = np.nan
df.iloc[2,1] = np.nan

# %%
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.166981        0.530027             NaN        0.746630
# 1        0.759591        0.538733        0.432435        0.211435
# 2        0.569297             NaN        0.780319        0.329073
# 3        0.502208        0.661269        0.501653        0.093722

# %%
df.isnull()
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0           False           False            True           False
# 1           False           False           False           False
# 2           False            True           False           False
# 3           False           False           False           False

# %%
df.isnull().sum()
# Out:
# Random value 1    0
# Random value 2    1
# Random value 3    1
# Random value 4    0
# dtype: int64

# %%
df['Random value 1'].dtype
# Out:
# dtype('float64')

# %%
df['Random value 2'].dtype
# Out:
# dtype('float64')

# %%
df['Random value 3'].dtype
# Out:
# dtype('float64')

# %%
df['Random value 4'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # TASK - 5
# Display the 'Random value 2' & 'Random value 3' columns with location method and index location method

# %%
df.loc[0:,'Random value 2':'Random value 3']
# Out:
#    Random value 2  Random value 3
# 0        0.530027             NaN
# 1        0.538733        0.432435
# 2             NaN        0.780319
# 3        0.661269        0.501653

# %%
df.iloc[0:,1:3]
# Out:
#    Random value 2  Random value 3
# 0        0.530027             NaN
# 1        0.538733        0.432435
# 2             NaN        0.780319
# 3        0.661269        0.501653
